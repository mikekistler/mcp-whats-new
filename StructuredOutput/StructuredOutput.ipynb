# %% [markdown]
# ## Tool Metadata

# %%
curl -s -X POST http://localhost:3001 `
-H "ProtocolVersion: 2025-06-18" `
-H "Accept: application/json, text/event-stream" `
-H "Content-Type: application/json" `
-d '{
    "jsonrpc": "2.0",
    "id": 1,
    "method": "tools/list"
}' | Where-Object { $_ -like "data:*" } | ForEach-Object { $_.Substring(5) } | jq
# Out:
# {
#   "result": {
#     "tools": [
#       {
#         "name": "get_products",
#         "description": "Gets a list of structured product data with detailed information.",
#         "inputSchema": {
#           "type": "object",
#           "properties": {
#             "count": {
#               "type": "integer",
#               "default": 5
#             }
#           }
#         },
#         "outputSchema": {
#           "type": "object",
#           "properties": {
#             "result": {
#               "type": "array",
#               "items": {
#                 "type": "object",
#                 "properties": {
#                   "id": {
#                     "description": "Unique identifier for the product",
#                     "type": "integer"
#                   },
#                   "name": {
#                     "description": "Name of the product",
#                     "type": "string"
#                   },
#                   "description": {
#                     "description": "Detailed description of the product",
#                     "type": "string"
#                   },
#                   "price": {
#                     "description": "Price of the product in currency",
#                     "type": "number"
#                   },
#                   "category": {
#                     "description": "Product category classification",
#                     "type": "string"
#                   },
#                   "brand": {
#                     "description": "Brand or manufacturer of the product",
#                     "type": "string"
#                   },
#                   "inStock": {
#                     "description": "Number of items currently in stock",
#                     "type": "integer"
#                   },
#                   "rating": {
#                     "description": "Customer rating from 0 to 5 stars",
#                     "type": "number"
#                   },
#                   "features": {
#                     "description": "List of product features and highlights",
#                     "type": "array",
#                     "items": {
#                       "type": "string"
#                     }
#                   },
#                   "specifications": {
#                     "description": "Technical specifications and details",
#                     "type": "object",
#                     "additionalProperties": {
#                       "type": "string"
#                     }
#                   }
#                 }
#               }
#             }
#           },
#           "required": [
#             "result"
#           ]
#         }
#       },
#       {
#         "name": "get_user_profile",
#         "description": "Gets a structured user profile with detailed information.",
#         "inputSchema": {
#           "type": "object",
#           "properties": {
#             "userId": {
#               "type": "string"
#             }
#           },
#           "required": [
#             "userId"
#           ]
#         },
#         "outputSchema": {
#           "type": "object",
#           "properties": {
#             "id": {
#               "description": "Unique identifier for the user",
#               "type": "string"
#             },
#             "firstName": {
#               "description": "User's first name",
#               "type": "string"
#             },
#             "lastName": {
#               "description": "User's last name",
#               "type": "string"
#             },
#             "email": {
#               "description": "User's email address",
#               "type": "string"
#             },
#             "age": {
#               "description": "User's age in years",
#               "type": "integer"
#             },
#             "address": {
#               "description": "User's physical address information",
#               "type": "object",
#               "properties": {
#                 "street": {
#                   "description": "Street address including house number and street name",
#                   "type": "string"
#                 },
#                 "city": {
#                   "description": "City name",
#                   "type": "string"
#                 },
#                 "state": {
#                   "description": "State or province name",
#                   "type": "string"
#                 },
#                 "zipCode": {
#                   "description": "Postal or ZIP code",
#                   "type": "string"
#                 },
#                 "country": {
#                   "description": "Country name",
#                   "type": "string"
#                 }
#               }
#             },
#             "preferences": {
#               "description": "User's application preferences and settings",
#               "type": "object",
#               "properties": {
#                 "theme": {
#                   "description": "User interface theme preference (e.g., 'dark', 'light')",
#                   "type": "string"
#                 },
#                 "language": {
#                   "description": "Preferred language code (e.g., 'en', 'es', 'fr')",
#                   "type": "string"
#                 },
#                 "notifications": {
#                   "description": "Whether the user wants to receive notifications",
#                   "type": "boolean"
#                 },
#                 "emailUpdates": {
#                   "description": "Whether the user wants to receive email updates",
#                   "type": "boolean"
#                 }
#               }
#             },
#             "createdAt": {
#               "description": "Timestamp when the user account was created",
#               "type": "string"
#             },
#             "lastLoginAt": {
#               "description": "Timestamp of the user's last login",
#               "type": "string"
#             }
#           }
#         }
#       },
#       {
#         "name": "get_sales_analytics",
#         "description": "Gets structured sales analytics data with metrics and trends.",
#         "inputSchema": {
#           "type": "object",
#           "properties": {
#             "period": {
#               "type": "string",
#               "default": "monthly"
#             }
#           }
#         },
#         "outputSchema": {
#           "type": "object",
#           "properties": {
#             "period": {
#               "description": "Time period for the sales analytics (e.g., 'Q1 2024', 'January 2024')",
#               "type": "string"
#             },
#             "totalRevenue": {
#               "description": "Total revenue generated during the period",
#               "type": "number"
#             },
#             "totalOrders": {
#               "description": "Total number of orders placed during the period",
#               "type": "integer"
#             },
#             "averageOrderValue": {
#               "description": "Average value per order during the period",
#               "type": "number"
#             },
#             "conversionRate": {
#               "description": "Conversion rate as a decimal (0.0 to 1.0)",
#               "type": "number"
#             },
#             "topProducts": {
#               "description": "List of top-selling products during the period",
#               "type": "array",
#               "items": {
#                 "type": "object",
#                 "properties": {
#                   "name": {
#                     "description": "Name of the top-selling product",
#                     "type": "string"
#                   },
#                   "sales": {
#                     "description": "Number of units sold",
#                     "type": "integer"
#                   },
#                   "revenue": {
#                     "description": "Total revenue generated by this product",
#                     "type": "number"
#                   }
#                 }
#               }
#             },
#             "regionalData": {
#               "description": "Sales data broken down by geographical region",
#               "type": "array",
#               "items": {
#                 "type": "object",
#                 "properties": {
#                   "region": {
#                     "description": "Name of the geographical region",
#                     "type": "string"
#                   },
#                   "revenue": {
#                     "description": "Total revenue from this region",
#                     "type": "number"
#                   },
#                   "orders": {
#                     "description": "Number of orders from this region",
#                     "type": "integer"
#                   }
#                 }
#               }
#             },
#             "generatedAt": {
#               "description": "Timestamp when this analytics report was generated",
#               "type": "string"
#             }
#           }
#         }
#       }
#     ]
#   },
#   "id": 1,
#   "jsonrpc": "2.0"
# }

# %% [markdown]
# ## Tool Call

# %%
curl -s -X POST http://localhost:3001 `
-H "ProtocolVersion: 2025-06-18" `
-H "Accept: application/json, text/event-stream" `
-H "Content-Type: application/json" `
-d '{
    "jsonrpc": "2.0",
    "id": 1,
    "method": "tools/call",
    "params": {
        "name": "get_products"
    }
}' | Where-Object { $_ -like "data:*" } | ForEach-Object { $_.Substring(5) } | jq
# Out:
# {
#   "result": {
#     "content": [
#       {
#         "type": "text",
#         "text": "[{\"id\":1,\"name\":\"Laptop Pro\",\"description\":\"High-quality laptop pro for professional use\",\"price\":474.51,\"category\":\"Hardware\",\"brand\":\"DeviceMax\",\"inStock\":48,\"rating\":4.1,\"features\":[\"Durable construction\",\"Modern design\",\"Easy to use\"],\"specifications\":{\"Weight\":\"2 lbs\",\"Dimensions\":\"18x13x2 inches\",\"Warranty\":\"2 years\"}},{\"id\":2,\"name\":\"Wireless Mouse\",\"description\":\"High-quality wireless mouse for professional use\",\"price\":517.74,\"category\":\"Accessories\",\"brand\":\"GadgetPro\",\"inStock\":71,\"rating\":4.2,\"features\":[\"Durable construction\",\"Modern design\",\"Easy to use\"],\"specifications\":{\"Weight\":\"3 lbs\",\"Dimensions\":\"11x12x3 inches\",\"Warranty\":\"2 years\"}},{\"id\":3,\"name\":\"Mechanical Keyboard\",\"description\":\"High-quality mechanical keyboard for professional use\",\"price\":392.52,\"category\":\"Peripherals\",\"brand\":\"GadgetPro\",\"inStock\":48,\"rating\":3.7,\"features\":[\"Durable construction\",\"Modern design\",\"Easy to use\"],\"specifications\":{\"Weight\":\"3 lbs\",\"Dimensions\":\"18x10x3 inches\",\"Warranty\":\"2 years\"}},{\"id\":4,\"name\":\"USB-C Hub\",\"description\":\"High-quality usb-c hub for professional use\",\"price\":227.01,\"category\":\"Electronics\",\"brand\":\"TechCorp\",\"inStock\":74,\"rating\":4.6,\"features\":[\"Durable construction\",\"Modern design\",\"Easy to use\"],\"specifications\":{\"Weight\":\"1 lbs\",\"Dimensions\":\"16x10x4 inches\",\"Warranty\":\"2 years\"}},{\"id\":5,\"name\":\"Monitor Stand\",\"description\":\"High-quality monitor stand for professional use\",\"price\":58.51,\"category\":\"Electronics\",\"brand\":\"ComponentPlus\",\"inStock\":99,\"rating\":3.6,\"features\":[\"Durable construction\",\"Modern design\",\"Easy to use\"],\"specifications\":{\"Weight\":\"3 lbs\",\"Dimensions\":\"16x12x3 inches\",\"Warranty\":\"2 years\"}}]"
#       }
#     ],
#     "structuredContent": {
#       "result": [
#         {
#           "id": 1,
#           "name": "Laptop Pro",
#           "description": "High-quality laptop pro for professional use",
#           "price": 474.51,
#           "category": "Hardware",
#           "brand": "DeviceMax",
#           "inStock": 48,
#           "rating": 4.1,
#           "features": [
#             "Durable construction",
#             "Modern design",
#             "Easy to use"
#           ],
#           "specifications": {
#             "Weight": "2 lbs",
#             "Dimensions": "18x13x2 inches",
#             "Warranty": "2 years"
#           }
#         },
#         {
#           "id": 2,
#           "name": "Wireless Mouse",
#           "description": "High-quality wireless mouse for professional use",
#           "price": 517.74,
#           "category": "Accessories",
#           "brand": "GadgetPro",
#           "inStock": 71,
#           "rating": 4.2,
#           "features": [
#             "Durable construction",
#             "Modern design",
#             "Easy to use"
#           ],
#           "specifications": {
#             "Weight": "3 lbs",
#             "Dimensions": "11x12x3 inches",
#             "Warranty": "2 years"
#           }
#         },
#         {
#           "id": 3,
#           "name": "Mechanical Keyboard",
#           "description": "High-quality mechanical keyboard for professional use",
#           "price": 392.52,
#           "category": "Peripherals",
#           "brand": "GadgetPro",
#           "inStock": 48,
#           "rating": 3.7,
#           "features": [
#             "Durable construction",
#             "Modern design",
#             "Easy to use"
#           ],
#           "specifications": {
#             "Weight": "3 lbs",
#             "Dimensions": "18x10x3 inches",
#             "Warranty": "2 years"
#           }
#         },
#         {
#           "id": 4,
#           "name": "USB-C Hub",
#           "description": "High-quality usb-c hub for professional use",
#           "price": 227.01,
#           "category": "Electronics",
#           "brand": "TechCorp",
#           "inStock": 74,
#           "rating": 4.6,
#           "features": [
#             "Durable construction",
#             "Modern design",
#             "Easy to use"
#           ],
#           "specifications": {
#             "Weight": "1 lbs",
#             "Dimensions": "16x10x4 inches",
#             "Warranty": "2 years"
#           }
#         },
#         {
#           "id": 5,
#           "name": "Monitor Stand",
#           "description": "High-quality monitor stand for professional use",
#           "price": 58.51,
#           "category": "Electronics",
#           "brand": "ComponentPlus",
#           "inStock": 99,
#           "rating": 3.6,
#           "features": [
#             "Durable construction",
#             "Modern design",
#             "Easy to use"
#           ],
#           "specifications": {
#             "Weight": "3 lbs",
#             "Dimensions": "16x12x3 inches",
#             "Warranty": "2 years"
#           }
#         }
#       ]
#     }
#   },
#   "id": 1,
#   "jsonrpc": "2.0"
# }
